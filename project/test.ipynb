# %%
import json
import pandas as pd
from pprint import pprint
import matplotlib.pyplot as plt
import networkx as nx

# %% [markdown]
# Load the JSON and create a master DataFrame of STIX objects

# %%
fn = "../enterprise-attack/enterprise-attack.json"
with open(fn, "r", encoding="utf-8") as f:
    stix = json.load(f)

objects = stix.get("objects", [])
# Master dataframe (keeps the raw dict for reference)
master_df = pd.DataFrame([{
    "id": o.get("id"),
    "type": o.get("type"),
    "name": o.get("name"),
    "description": o.get("description"),
    "created": o.get("created"),
    "modified": o.get("modified"),
    "raw": o
} for o in objects])

master_df.head()
# Out:
#                                                   id                type  \
# 0  x-mitre-collection--1f5f1533-f617-4ca8-9ab4-6a...  x-mitre-collection
# 1  x-mitre-matrix--eafc1b4c-5e56-4965-bd4e-66a6a8...      x-mitre-matrix
# 2  course-of-action--00d7d21b-69d6-4797-88a2-c86f...    course-of-action
# 3  course-of-action--02f0f92a-0a51-4c94-9bda-6437...    course-of-action
# 4  course-of-action--03c0c586-50ed-45a7-95f4-f496...    course-of-action
#
#                               name  \
# 0                Enterprise ATT&CK
# 1                Enterprise ATT&CK
# 2   Password Filter DLL Mitigation
# 3  Space after Filename Mitigation
# 4           HISTCONTROL Mitigation
#
#                                          description  \
# 0  ATT&CK for Enterprise provides a knowledge bas...
# 1  Below are the tactics and technique representi...
# 2  Ensure only valid password filters are registe...
# 3  Prevent files from having a trailing space aft...
# 4  Prevent users from changing the <code>HISTCONT...
#
#                     created                  modified  \
# 0  2018-01-17T12:56:55.080Z  2025-05-06T14:00:00.188Z
# 1  2018-10-17T00:14:20.652Z  2025-04-25T14:41:40.982Z
# 2  2018-10-17T00:14:20.652Z  2025-04-18T17:59:39.912Z
# 3  2018-10-17T00:14:20.652Z  2025-04-18T17:59:40.127Z
# 4  2018-10-17T00:14:20.652Z  2025-04-18T17:59:40.291Z
#
#                                                  raw
# 0  {'type': 'x-mitre-collection', 'id': 'x-mitre-...
# 1  {'type': 'x-mitre-matrix', 'spec_version': '2....
# 2  {'type': 'course-of-action', 'spec_version': '...
# 3  {'type': 'course-of-action', 'spec_version': '...
# 4  {'type': 'course-of-action', 'spec_version': '...

# %% [markdown]
# Extract techniques (ATT&CK `attack-pattern` objects)

# %%
tech_objs = [o for o in objects if o.get("type") == "attack-pattern"]

def technique_row(o):
    # external id e.g. T1003 usually in external_references where source_name == 'mitre-attack'
    ext_refs = o.get("external_references", [])
    mitre_ref = next((r for r in ext_refs if r.get("source_name") == "mitre-attack"), {})
    external_id = mitre_ref.get("external_id")
    # kill_chain_phases may contain tactic phase names
    kcp = o.get("kill_chain_phases") or o.get("kill_chain_phases", []) or []
    phases = [p.get("phase_name") for p in kcp if isinstance(p, dict) and p.get("phase_name")]
    platforms = o.get("x_mitre_platforms") or o.get("x-mitre-platforms") or []
    data_sources = o.get("x_mitre_data_sources") or []
    return {
        "id": o.get("id"),
        "tech_name": o.get("name"),
        "external_id": external_id,
        "description": o.get("description"),
        "platforms": platforms,
        "kill_chain_phases": phases,
        "raw": o
    }

tech_df = pd.DataFrame([technique_row(o) for o in tech_objs])
tech_df.head()
# Out:
#                                                   id  \
# 0  attack-pattern--0042a9f5-f053-4769-b3ef-9ad018...
# 1  attack-pattern--005a06c6-14bf-4118-afa0-ebcd8a...
# 2  attack-pattern--005cc321-08ce-4d17-b1ea-cb5275...
# 3  attack-pattern--00d0b012-8a03-410e-95de-5826bf...
# 4  attack-pattern--00f90846-cbd1-4fc5-9233-df5c2b...
#
#                        tech_name external_id  \
# 0  Extra Window Memory Injection   T1055.011
# 1                 Scheduled Task   T1053.005
# 2                 Socket Filters   T1205.002
# 3   Indicator Removal from Tools       T1066
# 4            Archive via Utility   T1560.001
#
#                                          description                platforms  \
# 0  Adversaries may inject malicious code into pro...                [Windows]
# 1  Adversaries may abuse the Windows Task Schedul...                [Windows]
# 2  Adversaries may attach filters to a network so...  [Linux, macOS, Windows]
# 3  If a malicious tool is detected and quarantine...  [Linux, macOS, Windows]
# 4  Adversaries may use utilities to compress and/...  [Linux, Windows, macOS]
#
#                                    kill_chain_phases  \
# 0            [defense-evasion, privilege-escalation]
# 1     [execution, persistence, privilege-escalation]
# 2  [defense-evasion, persistence, command-and-con...
# 3                                  [defense-evasion]
# 4                                       [collection]
#
#                                                  raw
# 0  {'type': 'attack-pattern', 'spec_version': '2....
# 1  {'type': 'attack-pattern', 'spec_version': '2....
# 2  {'type': 'attack-pattern', 'spec_version': '2....
# 3  {'type': 'attack-pattern', 'spec_version': '2....
# 4  {'type': 'attack-pattern', 'spec_version': '2....

# %% [markdown]
# Extract tactics (from kill_chain_phases) — canonicalize into a DataFrame

# %%
# Many ATT&CK bundles don't provide tactic objects as separate 'x-mitre-tactic' entries,
# but techniques include kill_chain_phases referencing 'mitre-attack' phase_name (tactic).
# We'll get the unique list of tactics from the techniques kill_chain_phases:

tactics = sorted({phase for phases in tech_df["kill_chain_phases"].tolist() for phase in phases if phase})
tactics_df = pd.DataFrame({"tactic": tactics})
tactics_df
# Out:
#                   tactic
# 0             collection
# 1    command-and-control
# 2      credential-access
# 3        defense-evasion
# 4              discovery
# 5              execution
# 6           exfiltration
# 7                 impact
# 8         initial-access
# 9       lateral-movement
# 10           persistence
# 11  privilege-escalation
# 12        reconnaissance
# 13  resource-development

# %% [markdown]
# Relationships DataFrame (useful for group->technique and other links)

# %%
rel_objs = [o for o in objects if o.get("type") == "relationship"]

rel_df = pd.DataFrame([{
    "id": o.get("id"),
    "relationship_type": o.get("relationship_type"),
    "source_ref": o.get("source_ref"),
    "target_ref": o.get("target_ref"),
    "description": o.get("description"),
    "raw": o
} for o in rel_objs])

rel_df.head()
# Out:
#                                                   id relationship_type  \
# 0  relationship--00038d0e-7fc7-41c3-9055-edb4d87e...              uses
# 1  relationship--0005fb3b-274a-4ac1-8fb2-51366fcd...         mitigates
# 2  relationship--00069454-a469-4905-97fd-b4057e86...           detects
# 3  relationship--000aa4d0-315e-40d7-b2b6-76e91ecf...              uses
# 4  relationship--00192a5f-9dc0-445a-b010-d77bd08a...              uses
#
#                                           source_ref  \
# 0      malware--6a21e3a4-5ffe-4581-af9a-6a54c7536f44
# 1  course-of-action--21da4fd4-27ad-4e9c-b93d-0b9b...
# 2  x-mitre-data-component--a7f22107-02e5-4982-906...
# 3  intrusion-set--01e28736-2ffc-455b-9880-ed4d140...
# 4      malware--425771c5-48b4-4ecd-9f95-74ed3fc9da59
#
#                                           target_ref  \
# 0  attack-pattern--707399d6-ab3e-4963-9315-d9d381...
# 1  attack-pattern--43c9bc06-715b-42db-972f-52d25c...
# 2  attack-pattern--18cffc21-3260-437e-80e4-4ab8bf...
# 3  attack-pattern--65f2d882-3f41-4d48-8a06-29af77...
# 4  attack-pattern--bf176076-b789-408e-8cba-7275e8...
#
#                                          description  \
# 0   [Explosive](https://attack.mitre.org/software...
# 1  Consider blocking download/transfer and execut...
# 2  Monitor network data for uncommon data flows. ...
# 3  [Indrik Spider](https://attack.mitre.org/group...
# 4  [SombRAT](https://attack.mitre.org/software/S0...
#
#                                                  raw
# 0  {'type': 'relationship', 'spec_version': '2.1'...
# 1  {'type': 'relationship', 'spec_version': '2.1'...
# 2  {'type': 'relationship', 'spec_version': '2.1'...
# 3  {'type': 'relationship', 'spec_version': '2.1'...
# 4  {'type': 'relationship', 'spec_version': '2.1'...

# %% [markdown]
# Map techniques to tactics (exploded rows, easy to group)

# %%
# explode kill_chain_phases into row-per-technique-per-tactic
tech_exploded = tech_df.explode("kill_chain_phases").rename(columns={"kill_chain_phases":"tactic"})
tech_exploded = tech_exploded[["id","external_id","tech_name","tactic","platforms"]]
tech_exploded.head()
# Out:
#                                                   id external_id  \
# 0  attack-pattern--0042a9f5-f053-4769-b3ef-9ad018...   T1055.011
# 0  attack-pattern--0042a9f5-f053-4769-b3ef-9ad018...   T1055.011
# 1  attack-pattern--005a06c6-14bf-4118-afa0-ebcd8a...   T1053.005
# 1  attack-pattern--005a06c6-14bf-4118-afa0-ebcd8a...   T1053.005
# 1  attack-pattern--005a06c6-14bf-4118-afa0-ebcd8a...   T1053.005
#
#                        tech_name                tactic  platforms
# 0  Extra Window Memory Injection       defense-evasion  [Windows]
# 0  Extra Window Memory Injection  privilege-escalation  [Windows]
# 1                 Scheduled Task             execution  [Windows]
# 1                 Scheduled Task           persistence  [Windows]
# 1                 Scheduled Task  privilege-escalation  [Windows]

# %% [markdown]
# ## Analyses and Plots

# %% [markdown]
# Count techniques per tactic

# %%
counts = tech_exploded.groupby("tactic")["id"].nunique().sort_values(ascending=False)
print(counts)

# simple bar plot
counts.plot(kind="bar", figsize=(10,5))
plt.title("Number of techniques per tactic (from kill_chain_phases)")
plt.ylabel("Technique count")
plt.xlabel("Tactic")
plt.tight_layout()
plt.show()
# Out:
# tactic
# defense-evasion         258
# persistence             180
# privilege-escalation    139
# credential-access        80
# execution                67
# command-and-control      55
# discovery                48
# resource-development     47
# reconnaissance           44
# collection               40
# impact                   38
# lateral-movement         34
# initial-access           25
# exfiltration             21
# Name: id, dtype: int64

# %% [markdown]
# Count techniques mentioned by intrusion-sets / groups (via relationships)

# %%
# typical ATT&CK IDs: intrusion-set objects have type 'intrusion-set'
# relationships often link intrusion-set -> attack-pattern (technique)
# we can find those refs and join back to technique external_id

# 1) get list of intrusion-set objects and a mapping id->name
intrusion_objs = [o for o in objects if o.get("type") == "intrusion-set"]
intrusion_map = {o["id"]: o.get("name") for o in intrusion_objs}

# 2) filter relationships where target_ref is an attack-pattern id
# Note: target_ref contains full STIX id; match to tech_df.id
rel_is_to_tech = rel_df[rel_df["target_ref"].isin(tech_df["id"])]
# attach intrusion-set name if source_ref is an intrusion-set
rel_is_to_tech["intrusion_set_name"] = rel_is_to_tech["source_ref"].map(intrusion_map)
rel_is_to_tech = rel_is_to_tech.dropna(subset=["intrusion_set_name"])
rel_is_to_tech = rel_is_to_tech.merge(tech_df[["id","external_id","tech_name"]], left_on="target_ref", right_on="id", how="left")
rel_is_to_tech.head()

# Count by intrusion-set
counts_by_is = rel_is_to_tech.groupby("intrusion_set_name")["external_id"].nunique().sort_values(ascending=False)
print(counts_by_is.head(20))
# Out:
# intrusion_set_name
# Kimsuky              103
# Lazarus Group         92
# APT28                 91
# APT41                 82
# Volt Typhoon          81
# Magic Hound           79
# Sandworm Team         79
# APT32                 78
# OilRig                76
# Turla                 68
# APT29                 66
# Wizard Spider         64
# Chimera               59
# MuddyWater            58
# Threat Group-3390     57
# Dragonfly             56
# APT38                 55
# Gamaredon Group       55
# TeamTNT               54
# FIN13                 53
# Name: external_id, dtype: int64
# /tmp/ipykernel_24477/2689066225.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rel_is_to_tech["intrusion_set_name"] = rel_is_to_tech["source_ref"].map(intrusion_map)

# %% [markdown]
# Build a bipartite graph (intrusion-set <-> technique)

# %%
# Build NetworkX bipartite graph
G = nx.Graph()
# add intrusion-set nodes
for is_id, is_name in intrusion_map.items():
    G.add_node(is_name, bipartite="intrusion-set")
# add technique nodes and edges
for _, row in rel_is_to_tech.iterrows():
    is_name = row["intrusion_set_name"]
    tech = f"{row['external_id'] or row['tech_name']}"
    G.add_node(tech, bipartite="technique")
    G.add_edge(is_name, tech)

# Draw a small subgraph (limit to top 10 intrusion-sets by degree to keep it readable)
top_is = counts_by_is.head(8).index.tolist()
sub_nodes = set(top_is)
for n in top_is:
    sub_nodes |= set(G.neighbors(n))
subG = G.subgraph(sub_nodes)

plt.figure(figsize=(12,8))
pos = nx.spring_layout(subG, k=0.5)
nx.draw(subG, pos, with_labels=True, node_size=3000, font_size=9)
plt.title("Intrusion-sets to Techniques (sample)")
plt.show()

# %%
# Filter relationships where source is intrusion-set and target is attack-pattern (technique)
rel_uses = rel_df[
    (rel_df["relationship_type"] == "uses") &
    (rel_df["source_ref"].str.startswith("intrusion-set")) &
    (rel_df["target_ref"].str.startswith("attack-pattern"))
].copy()

# Map intrusion-set names
rel_uses["intrusion_set_name"] = rel_uses["source_ref"].map(intrusion_map)

# Join in technique info (external_id and name)
rel_uses = rel_uses.merge(
    tech_df[["id", "external_id", "tech_name"]],
    left_on="target_ref", right_on="id", how="left"
)

rel_uses.head()
# Out:
#                                                 id_x relationship_type  \
# 0  relationship--000aa4d0-315e-40d7-b2b6-76e91ecf...              uses
# 1  relationship--002f1039-f4c5-4c60-b8ac-ced374be...              uses
# 2  relationship--0038b0b8-f51c-4fd1-8b04-2fd7ebd1...              uses
# 3  relationship--00561c3c-345e-4578-95c3-b7e0a95d...              uses
# 4  relationship--0068ee65-0945-4f69-ba81-163ffbc0...              uses
#
#                                           source_ref  \
# 0  intrusion-set--01e28736-2ffc-455b-9880-ed4d140...
# 1  intrusion-set--b7f627e2-0817-4cd5-8d50-e75f8aa...
# 2  intrusion-set--dd2d9ca6-505b-4860-a604-233685b...
# 3  intrusion-set--3753cc21-2dae-4dfb-8481-d004e74...
# 4  intrusion-set--f8cb7b36-62ef-4488-8a6d-a7033e3...
#
#                                           target_ref  \
# 0  attack-pattern--65f2d882-3f41-4d48-8a06-29af77...
# 1  attack-pattern--10ffac09-e42d-4f56-ab20-db94c6...
# 2  attack-pattern--635cbe30-392d-4e27-978e-667743...
# 3  attack-pattern--ef67e13e-5598-4adc-bdb2-998225...
# 4  attack-pattern--970a3432-3237-47ad-bcca-7d8cbb...
#
#                                          description  \
# 0  [Indrik Spider](https://attack.mitre.org/group...
# 1  [LuminousMoth](https://attack.mitre.org/groups...
# 2  [Wizard Spider](https://attack.mitre.org/group...
# 3  [FIN7](https://attack.mitre.org/groups/G0046) ...
# 4  [WIRTE](https://attack.mitre.org/groups/G0090)...
#
#                                                  raw intrusion_set_name  \
# 0  {'type': 'relationship', 'spec_version': '2.1'...      Indrik Spider
# 1  {'type': 'relationship', 'spec_version': '2.1'...       LuminousMoth
# 2  {'type': 'relationship', 'spec_version': '2.1'...      Wizard Spider
# 3  {'type': 'relationship', 'spec_version': '2.1'...               FIN7
# 4  {'type': 'relationship', 'spec_version': '2.1'...              WIRTE
#
#                                                 id_y external_id  \
# 0  attack-pattern--65f2d882-3f41-4d48-8a06-29af77...   T1003.001
# 1  attack-pattern--10ffac09-e42d-4f56-ab20-db94c6...       T1539
# 2  attack-pattern--635cbe30-392d-4e27-978e-667743...   T1136.001
# 3  attack-pattern--ef67e13e-5598-4adc-bdb2-998225...   T1204.001
# 4  attack-pattern--970a3432-3237-47ad-bcca-7d8cbb...   T1059.001
#
#                   tech_name
# 0              LSASS Memory
# 1  Steal Web Session Cookie
# 2             Local Account
# 3            Malicious Link
# 4                PowerShell

# %%
# Count total number of unique intrusion sets using each technique
tech_use_counts = (
    rel_uses.groupby(["external_id", "tech_name"])["intrusion_set_name"]
    .nunique()  # number of distinct intrusion sets per technique
    .reset_index(name="use_count")
    .sort_values("use_count", ascending=False)
)

tech_use_counts.head(10)
# Out:
#     external_id                                   tech_name  use_count
# 203   T1204.002                              Malicious File         83
# 150       T1105                       Ingress Tool Transfer         83
# 88    T1059.001                                  PowerShell         79
# 340   T1566.001                    Spearphishing Attachment         77
# 393   T1588.002                                        Tool         75
# 89    T1059.003                       Windows Command Shell         68
# 53    T1036.005  Match Legitimate Resource Name or Location         59
# 110   T1071.001                               Web Protocols         55
# 272   T1547.001          Registry Run Keys / Startup Folder         54
# 124       T1082                System Information Discovery         54

# %%
# Sort by use_count descending and keep top 20 techniques
top_techs = tech_use_counts.sort_values("use_count", ascending=False).head(20)

plt.figure(figsize=(12, 6))
plt.barh(
    top_techs["tech_name"][::-1],   # ← show names on Y-axis
    top_techs["use_count"][::-1],   # ← counts on X-axis
)

plt.title("Top 20 Most Used MITRE ATT&CK Techniques (by Intrusion Sets)")
plt.xlabel("Number of Intrusion Sets Using Technique")
plt.ylabel("Technique Name")
plt.tight_layout()
plt.show()
