# %%
import sys
from pathlib import Path

ROOT = Path().resolve().parents[1] # go up n levels (adjust as needed)
sys.path.append(str(ROOT))

from config import PROJECT_ROOT, APT_ROOT
from apt_project import *

# %%
import pandas as pd

# %%
master_df
# Out:
#                                                       id                type  \
# 0      x-mitre-collection--1f5f1533-f617-4ca8-9ab4-6a...  x-mitre-collection
# 1      x-mitre-matrix--eafc1b4c-5e56-4965-bd4e-66a6a8...      x-mitre-matrix
# 2      course-of-action--00d7d21b-69d6-4797-88a2-c86f...    course-of-action
# 3      course-of-action--02f0f92a-0a51-4c94-9bda-6437...    course-of-action
# 4      course-of-action--03c0c586-50ed-45a7-95f4-f496...    course-of-action
# ...                                                  ...                 ...
# 24767  relationship--fff9a9cb-3032-4f18-a626-ce34a82e...        relationship
# 24768  relationship--ffff35dc-3741-4fba-9680-f0fbe321...        relationship
# 24769  relationship--ffffed15-5695-44b9-b85b-89ba8187...        relationship
# 24770     identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5            identity
# 24771  marking-definition--fa42a846-8d90-4e51-bc29-71...  marking-definition
#
#                                   name  \
# 0                    Enterprise ATT&CK
# 1                    Enterprise ATT&CK
# 2       Password Filter DLL Mitigation
# 3      Space after Filename Mitigation
# 4               HISTCONTROL Mitigation
# ...                                ...
# 24767                             None
# 24768                             None
# 24769                             None
# 24770            The MITRE Corporation
# 24771                             None
#
#                                              description  \
# 0      ATT&CK for Enterprise provides a knowledge bas...
# 1      Below are the tactics and technique representi...
# 2      Ensure only valid password filters are registe...
# 3      Prevent files from having a trailing space aft...
# 4      Prevent users from changing the <code>HISTCONT...
# ...                                                  ...
# 24767  [ToddyCat](https://attack.mitre.org/groups/G10...
# 24768   [Bisonal](https://attack.mitre.org/software/S...
# 24769  [ZxShell](https://attack.mitre.org/software/S0...
# 24770
# 24771                                               None
#
#                         created                  modified  \
# 0      2018-01-17T12:56:55.080Z  2025-11-13T14:00:00.188Z
# 1      2018-10-17T00:14:20.652Z  2025-04-25T14:41:40.982Z
# 2      2018-10-17T00:14:20.652Z  2025-04-18T17:59:39.912Z
# 3      2018-10-17T00:14:20.652Z  2025-04-18T17:59:40.127Z
# 4      2018-10-17T00:14:20.652Z  2025-04-18T17:59:40.291Z
# ...                         ...                       ...
# 24767  2024-01-23T20:36:19.677Z  2025-04-16T23:00:48.213Z
# 24768  2022-01-27T18:04:46.484Z  2025-04-16T23:00:48.437Z
# 24769  2019-09-24T14:19:05.322Z  2025-04-28T16:19:23.875Z
# 24770  2017-06-01T00:00:00.000Z  2025-03-19T15:00:40.855Z
# 24771  2017-06-01T00:00:00.000Z                      None
#
#                                                      raw
# 0      {'type': 'x-mitre-collection', 'id': 'x-mitre-...
# 1      {'type': 'x-mitre-matrix', 'spec_version': '2....
# 2      {'type': 'course-of-action', 'spec_version': '...
# 3      {'type': 'course-of-action', 'spec_version': '...
# 4      {'type': 'course-of-action', 'spec_version': '...
# ...                                                  ...
# 24767  {'type': 'relationship', 'spec_version': '2.1'...
# 24768  {'type': 'relationship', 'spec_version': '2.1'...
# 24769  {'type': 'relationship', 'spec_version': '2.1'...
# 24770  {'modified': '2025-03-19T15:00:40.855Z', 'name...
# 24771  {'definition': {'statement': 'Copyright 2015-2...
#
# [24772 rows x 7 columns]

# %%
tech_df.head()
# Out:
#                                                   id  \
# 0  attack-pattern--0042a9f5-f053-4769-b3ef-9ad018...
# 1  attack-pattern--005a06c6-14bf-4118-afa0-ebcd8a...
# 2  attack-pattern--005cc321-08ce-4d17-b1ea-cb5275...
# 3  attack-pattern--00d0b012-8a03-410e-95de-5826bf...
# 4  attack-pattern--00f90846-cbd1-4fc5-9233-df5c2b...
#
#                        tech_name external_id  \
# 0  Extra Window Memory Injection   T1055.011
# 1                 Scheduled Task   T1053.005
# 2                 Socket Filters   T1205.002
# 3   Indicator Removal from Tools       T1066
# 4            Archive via Utility   T1560.001
#
#                                          description                platforms  \
# 0  Adversaries may inject malicious code into pro...                [Windows]
# 1  Adversaries may abuse the Windows Task Schedul...                [Windows]
# 2  Adversaries may attach filters to a network so...  [Linux, macOS, Windows]
# 3  If a malicious tool is detected and quarantine...  [Linux, macOS, Windows]
# 4  Adversaries may use utilities to compress and/...  [Linux, macOS, Windows]
#
#                                    kill_chain_phases  \
# 0            [defense-evasion, privilege-escalation]
# 1     [execution, persistence, privilege-escalation]
# 2  [defense-evasion, persistence, command-and-con...
# 3                                  [defense-evasion]
# 4                                       [collection]
#
#                                                  raw
# 0  {'type': 'attack-pattern', 'spec_version': '2....
# 1  {'type': 'attack-pattern', 'spec_version': '2....
# 2  {'type': 'attack-pattern', 'spec_version': '2....
# 3  {'type': 'attack-pattern', 'spec_version': '2....
# 4  {'type': 'attack-pattern', 'spec_version': '2....

# %%
umd_apts_df
# Out:
#                  slug  original_method  event_date reported_date  year  month  \
# 0    51de7a6f8a84858e                1  2014-06-30           NaN  2014      6
# 1    2c0603efa7d7541b                1  2015-02-28           NaN  2015      2
# 2    1147a5bf27ee80f6                1  2015-03-01           NaN  2015      3
# 3    649f14c0fd38146e                1  2015-05-31           NaN  2015      5
# 4    c786e72aab5694ab                1  2015-05-31           NaN  2015      5
# ..                ...              ...         ...           ...   ...    ...
# 420  z1r8m5x2c9v4k7t3                1  2025-03-25    2025-10-23  2025      3
# 421  q6v2r9x1c7m5t3k8                1  2025-09-01    2025-10-24  2025      9
# 422  z7m3t1p9v4x2k8r5                1  2025-07-15    2025-10-21  2025      7
# 423  b9e1f4d2c7a3e805                1  2025-09-01    2025-10-30  2025      9
# 424  f1d3b7e9c2a4f608                1  2025-09-01    2025-10-30  2025      9
#
#                                                  actor    actor_type  \
# 0                                    Green Dragon Crew    Hacktivist
# 1                                       f AKA @Cleaver  Undetermined
# 2    Ministry of State Security's (MSS) Guangdong S...  Nation-State
# 3                                                APT32  Nation-State
# 4                                                APT32  Nation-State
# ..                                                 ...           ...
# 420  NGB 3rd Technical Surveillance Bureau (Lazarus...  Nation-state
# 421                          APT36 (Transparent Tribe)  Nation-state
# 422  Ministry of State Security's (MSS) (Salt Typhoon)  Nation-state
# 423                                            UNC6384  Nation-State
# 424                                           UNC6384   Nation-State
#
#                                           organization  industry_code  ...  \
# 0                                           Privatbank             52  ...
# 1                                        frontalot.com             81  ...
# 2                                         Hanford Site             92  ...
# 3                      Armed Forces of the Philippines             92  ...
# 4                                     ASEAN Investment             92  ...
# ..                                                 ...            ...  ...
# 420            Undisclosed European drone manufacturer             31  ...
# 421  Undisclosed Indian government or infrastructur...             92  ...
# 422    Undisclosed European telecommunications company             51  ...
# 423            Undisclosed Belgian Diplomatic Entities             92  ...
# 424          Undisclosed Hungarian Diplomatic Entities             92  ...
#
#                                               org_data  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 420                                      None reported
# 421                                 Directory listings
# 422                                      None reported
# 423  Undisclosed volume of diplomatic correspondenc...
# 424  Undisclosed volume of diplomatic correspondenc...
#
#                                              cust_data  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 420                                      None reported
# 421                                      None reported
# 422             AD/infra configuration and credentials
# 423  Undisclosed volume of diplomatic correspondenc...
# 424  Undisclosed volume of diplomatic correspondenc...
#
#                                            description  \
# 0    Hackers from the Green Dragon Crew hack Privat...
# 1    f AKA @CIeaver hacks frontalot.com and dumps a...
# 2    Hackers conducted a combination of financially...
# 3    Vietnamese threat actor Ocean Lotus has compro...
# 4    Vietnamese threat actor Ocean Lotus has compro...
# ..                                                 ...
# 420  North Korean operators approached European def...
# 421  Pakistan-linked APT36 used themed lures and HT...
# 422  China-nexus operators breached a telecom by ex...
# 423  China-linked UNC6384 conducted a cyber-espiona...
# 424  China-linked UNC6384 conducted a cyber-espiona...
#
#                                             source_url  \
# 0               http://en.itar-tass.com/economy/738359
# 1    https://web.archive.org/web/20150315024644/htt...
# 2    https://www.politico.com/news/2020/07/21/doj-c...
# 3    https://www.volexity.com/blog/2017/11/06/ocean...
# 4    https://www.volexity.com/blog/2017/11/06/ocean...
# ..                                                 ...
# 420  https://thehackernews.com/2025/10/north-korean...
# 421  https://thehackernews.com/2025/10/apt36-target...
# 422  https://hackread.com/salt-typhoon-apt-telecom-...
# 423  https://therecord.media/belgium-hungary-diplom...
# 424  https://therecord.media/belgium-hungary-diplom...
#
#                       country                                actor_country  \
# 0                     Ukraine                                      Ukraine
# 1    United States of America                                 Undetermined
# 2    United States of America                                        China
# 3                 Philippines                                     Viet Nam
# 4                Undetermined                                     Viet Nam
# ..                        ...                                          ...
# 420              Undetermined  Korea (the Democratic People's Republic of)
# 421                     India                                     Pakistan
# 422              Undetermined                                        China
# 423                   Belgium                                        China
# 424                   Hungary                                        China
#
#             state        county change_log          apt_group
# 0             NaN           NaN        NaN           dragonok
# 1    Undetermined  Undetermined        NaN            cleaver
# 2      Washington        Benton        NaN               apt3
# 3             NaN           NaN        NaN              apt32
# 4             NaN           NaN        NaN              apt32
# ..            ...           ...        ...                ...
# 420  Undetermined  Undetermined        NaN      lazarus group
# 421           NaN           NaN        NaN  transparent tribe
# 422  Undetermined  Undetermined        NaN       salt typhoon
# 423           NaN           NaN        NaN      mustang panda
# 424           NaN           NaN        NaN      mustang panda
#
# [425 rows x 28 columns]
